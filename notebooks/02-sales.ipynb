# %% [markdown]
# # Revenue Modeling: Sales
#
# **Purpose:** For the tax revenue of interest, explore forecasts, testing out different combinations of
# endog and exog variables.
#
# Once the best fit is determined, we can plug the parameters into the main "parameters.yml" file and run reproducible model fits through the command line using `fyp-analysis run`.

# %%
TAX_NAME = "Sales"
TAX_BASE_COLUMN = f"{TAX_NAME}Base"

# %% [markdown]
# ## Software Setup

# %% [markdown]
# If changes are made to the analysis code, run the below cell to reload the changes:

# %%
# %reload_kedro
# Out:
# 2021-07-02 14:41:26,524 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2021-07-02 14:41:26,705 - root - INFO - ** Kedro project Five Year Plan Analysis
# 2021-07-02 14:41:26,706 - root - INFO - Defined global variable `context`, `session` and `catalog`

# %% [markdown]
# Imports:

# %%
# Base imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from phila_style.matplotlib import get_theme

# Prediction functions
from fyp_analysis.pipelines.modeling.predict import (
    get_possible_endog_variables,
    run_possible_models,
    fit_var_model,
    plot_forecast_results,
    plot_projection_comparison,
    aggregate_to_fiscal_year,
    get_forecasts_from_fits,
)

# The main preprocess pipeline
from fyp_analysis.pipelines.data_processing.preprocess import PreprocessPipeline
from fyp_analysis.extras.datasets import load_cbo_data, Taxes

# %%
pd.options.display.max_columns = 999

# %% [markdown]
# ## Parameter Setup

# %% [markdown]
# Set up the data catalog. We can use `DATA.load()` to load specific data instances.

# %%
DATA = context.catalog

# %% [markdown]
# Available data:

# %%
DATA.list()
# Out:
# ['economic_indicators',
#  'quarterly_features_raw',
#  'quarterly_features_cbo_imputed',
#  'features_and_bases',
#  'features_and_bases_sa',
#  'stationary_guide',
#  'final_unscaled_features',
#  'final_scaled_features',
#  'scaled_feature_correlations',
#  'grangers_matrix',
#  'possible_endog_variables',
#  'plan_details',
#  'wage_fit_params',
#  'sales_fit_params',
#  'net_income_fit_params',
#  'gross_receipts_fit_params',
#  'rtt_fit_params',
#  'parking_fit_params',
#  'amusement_fit_params',
#  'npt_fit_params',
#  'parameters',
#  'params:fresh_indicators',
#  'params:seasonal_adjustments',
#  'params:min_feature_year',
#  'params:max_fit_date',
#  'params:grangers_maxlag',
#  'params:grangers_max_date',
#  'params:plan_start_year',
#  'params:cbo_forecast_date']

# %% [markdown]
# Load the parameter dict too:

# %%
PARAMS = context.params

# %%
PARAMS
# Out:
# {'fresh_indicators': False,
#  'seasonal_adjustments': ['ActivityLicensesPhilly',
#   'BizLicensesPhilly',
#   'BuildingPermitsPhilly',
#   'CPIPhillyMSA',
#   'ContinuedClaimsPA',
#   'WeeklyEconomicIndex',
#   'DeedTransfersPhilly',
#   'InitialClaimsPA',
#   'UncertaintyIndex',
#   'UnemploymentPhilly'],
#  'min_feature_year': 1996,
#  'max_fit_date': '2021-06-30',
#  'grangers_maxlag': 6,
#  'grangers_max_date': '2019-12-31',
#  'plan_start_year': 2022,
#  'cbo_forecast_date': 'latest'}

# %% [markdown]
# Extract specific parameters:

# %%
# Trim features to this start year
min_year = PARAMS["min_feature_year"]

# When is the CBO forecast from?
cbo_forecast_date = PARAMS["cbo_forecast_date"]

# First fiscal year of the plan
plan_start_year = PARAMS["plan_start_year"]

# %% [markdown]
# ## Data Setup

# %% [markdown]
# Load the correlation matrix and Granger matrix:

# %%
C = DATA.load("scaled_feature_correlations") # correlation matrix
G = DATA.load("grangers_matrix") # Granger matrix
# Out:
# 2021-07-02 14:41:27,603 - kedro.io.data_catalog - INFO - Loading data from `scaled_feature_correlations` (ExcelDataSet)...
# 2021-07-02 14:41:27,718 - kedro.io.data_catalog - INFO - Loading data from `grangers_matrix` (ExcelDataSet)...

# %% [markdown]
# Load taxes object responsible for loading historical tax data"

# %%
# Load the Plan details we are using
plan_details = DATA.load("plan_details")

# All taxes
all_taxes = Taxes(plan_details)

# This tax
this_tax = all_taxes[TAX_NAME]
# Out:
# 2021-07-02 14:41:27,837 - kedro.io.data_catalog - INFO - Loading data from `plan_details` (PlanDetailsYAMLDataSet)...

# %% [markdown]
# Data associated with a tax is stored in the `.data` attribute:

# %%
this_tax.data.head()
# Out:
#    fiscal_quarter  fiscal_year  SalesRevenue  rate     SalesBase
# 0               1         1996    21568090.0  0.01  2.156809e+09
# 1               2         1996    21466668.0  0.01  2.146667e+09
# 2               3         1996    22027006.0  0.01  2.202701e+09
# 3               4         1996    17073290.0  0.01  1.707329e+09
# 4               1         1997    21416742.0  0.01  2.141674e+09

# %% [markdown]
# Load the final unscaled features:

# %%
unscaled_features = DATA.load("final_unscaled_features")
# Out:
# 2021-07-02 14:41:28,451 - kedro.io.data_catalog - INFO - Loading data from `final_unscaled_features` (CSVDataSet)...

# %%
unscaled_features.head()
# Out:
#             YieldCurve  SahmRule  WagesPhillyMSA  NonfarmEmployeesPhillyMSA  \
# Date
# 1996-01-01    0.640323  0.133333      633.494864                2488.200000
# 1996-04-01    0.603281 -0.023333      634.204732                2518.700000
# 1996-07-01    0.600000 -0.066667      634.799371                2526.300000
# 1996-10-01    0.550484  0.033333      645.667612                2537.900000
# 1997-01-01    0.522333  0.120000      651.303280                2556.266667
#
#             NonfarmEmployeesPhilly  PersonalSavingsRate  NYCGasPrice  \
# Date
# 1996-01-01              673.300000             6.666667     0.540810
# 1996-04-01              673.933333             6.500000     0.641175
# 1996-07-01              675.900000             6.666667     0.616141
# 1996-10-01              672.033333             6.400000     0.676531
# 1997-01-01              666.600000             6.266667     0.638361
#
#              CarSales  RealRetailFoodServiceSales  UnemploymentRate  \
# Date
# 1996-01-01  15.481000               136411.666667          5.533333
# 1996-04-01  15.571667               137903.333333          5.500000
# 1996-07-01  15.364667               138152.333333          5.266667
# 1996-10-01  15.401000               139499.000000          5.333333
# 1997-01-01  15.589667               140960.666667          5.233333
#
#                    PPI  UnemploymentPhillyMSA  UnemploymentPhilly  \
# Date
# 1996-01-01  126.300000               5.666667            7.615251
# 1996-04-01  127.833333               5.466667            7.303317
# 1996-07-01  128.166667               5.366667            7.134090
# 1996-10-01  128.433333               5.266667            7.227878
# 1997-01-01  128.500000               5.100000            7.045607
#
#             CorporateProfits    RealGDP  AlcoholSales  PrimeEPOP  \
# Date
# 1996-01-01           772.255  10817.896   1929.333333  79.866667
# 1996-04-01           784.776  10998.322   1930.666667  80.000000
# 1996-07-01           790.044  11096.976   1944.000000  80.433333
# 1996-10-01           810.914  11212.205   1906.666667  80.533333
# 1997-01-01           839.036  11284.587   1950.333333  80.500000
#
#             UncertaintyIndex  HousePriceIndexPhillyMSA  \
# Date
# 1996-01-01         85.211652                    105.35
# 1996-04-01         76.013567                    103.48
# 1996-07-01         76.992374                    102.40
# 1996-10-01         62.134681                    103.38
# 1997-01-01         58.548248                    103.72
#
#             BuildingPermitsPhillyMSA  EconomicConditionsPhillyMSA  \
# Date
# 1996-01-01               1192.461261                     2.993333
# 1996-04-01               1419.918127                     4.320000
# 1996-07-01               1450.454374                     2.470000
# 1996-10-01               1585.019678                     3.286667
# 1997-01-01               1665.828907                     3.503333
#
#             CPIPhillyMSA  InitialClaimsPA  ContinuedClaimsPA  \
# Date
# 1996-01-01    161.128928     24286.348514      183207.426031
# 1996-04-01    162.290804     21465.862561      162774.104738
# 1996-07-01    163.260178     20989.538331      156320.048762
# 1996-10-01    164.630069     21427.940357      153523.202698
# 1997-01-01    165.722588     18587.041742      149251.881603
#
#             NewManufacturingOrders  ConsumerConfidence  \
# Date
# 1996-01-01            48964.666667          100.506111
# 1996-04-01            50054.333333          100.703103
# 1996-07-01            50550.333333          101.087051
# 1996-10-01            51995.000000          101.427253
# 1997-01-01            53479.333333          101.677271
#
#             ManufacturingHoursWorked          PCE  \
# Date
# 1996-01-01                 40.700000  5130.600000
# 1996-04-01                 41.366667  5220.533333
# 1996-07-01                 41.500000  5274.500000
# 1996-10-01                 41.533333  5352.766667
# 1997-01-01                 41.600000  5433.100000
#
#             RealDisposablePersonalIncome  HousingStarts  HousingSupply  \
# Date
# 1996-01-01                   7867.333333    1460.666667       5.966667
# 1996-04-01                   7939.400000    1495.666667       5.966667
# 1996-07-01                   8003.700000    1501.333333       5.300000
# 1996-10-01                   8046.366667    1417.000000       5.266667
# 1997-01-01                   8123.000000    1432.666667       4.433333
#
#             GovtSocialBenefits  GDPPriceIndex       GDP  PCEPriceIndex  \
# Date
# 1996-01-01             674.991         72.700  7868.468      72.700000
# 1996-04-01             680.667         72.997  8032.840      73.186667
# 1996-07-01             683.711         73.352  8131.408      73.498667
# 1996-10-01             688.911         73.662  8259.771      73.999333
# 1997-01-01             704.464         73.992  8362.655      74.326000
#
#                   CPIU  10YearTreasury  3MonthTreasury  FedFundsRate  \
# Date
# 1996-01-01  155.066667        5.910000        4.930000      5.363333
# 1996-04-01  156.400000        6.720000        5.020000      5.243333
# 1996-07-01  157.300000        6.780000        5.096667      5.306667
# 1996-10-01  158.666667        6.343333        4.976667      5.280000
# 1997-01-01  159.633333        6.563333        5.060000      5.276667
#
#             OilPriceWTI  FHFAHousePriceIndex  NonfarmEmployment  \
# Date
# 1996-01-01    19.760000               113.72      118682.666667
# 1996-04-01    21.696667               114.47      119471.000000
# 1996-07-01    22.390000               115.21      120208.000000
# 1996-10-01    24.606667               115.87      120923.000000
# 1997-01-01    22.760000               116.60      121676.000000
#
#             PersonalIncome  Wage&Salaries  NonresidentialInvestment  \
# Date
# 1996-01-01        6520.965    3524.466667                  1003.747
# 1996-04-01        6649.846    3589.933333                  1026.468
# 1996-07-01        6725.853    3647.233333                  1058.965
# 1996-10-01        6817.457    3704.266667                  1083.597
# 1997-01-01        6939.356    3776.366667                  1107.299
#
#             ResidentialInvestment  TotalBusinessSales       SP500  \
# Date
# 1996-01-01                344.725       665407.333333  637.010000
# 1996-04-01                361.399       683338.666667  658.966667
# 1996-07-01                364.315       690877.000000  660.543333
# 1996-10-01                361.806       699627.333333  726.793333
# 1997-01-01                365.359       713321.666667  785.590000
#
#             MedianHomeValuePhilly  AmusementBase  GrossReceiptsBase  \
# Date
# 1996-01-01           70409.666667     25221361.2       2.187766e+08
# 1996-04-01           70070.666667     36110132.0       1.794259e+09
# 1996-07-01           69872.333333     45949333.4       1.363051e+08
# 1996-10-01           69969.333333     56777070.2       4.502762e+07
# 1997-01-01           70345.666667     26804719.4       2.626964e+08
#
#             NetIncomeBase       NPTBase   ParkingBase       RTTBase  \
# Date
# 1996-01-01   2.247482e+08  3.846310e+07  4.505538e+07  4.173158e+08
# 1996-04-01   1.843234e+09  2.124595e+08  4.785091e+07  3.134791e+08
# 1996-07-01   1.376918e+08  1.790954e+07  4.440285e+07  4.318287e+08
# 1996-10-01   4.548571e+07  2.239441e+07  4.687521e+07  5.769549e+08
# 1997-01-01   2.653690e+08  4.589743e+07  4.612029e+07  3.985260e+08
#
#                SalesBase      WageBase
# Date
# 1996-01-01  2.202701e+09  5.879433e+09
# 1996-04-01  1.707329e+09  5.672519e+09
# 1996-07-01  2.141674e+09  5.718973e+09
# 1996-10-01  2.126915e+09  5.793457e+09
# 1997-01-01  2.293904e+09  6.089935e+09

# %% [markdown]
# The final scaled features:

# %%
scaled_features = DATA.load("final_scaled_features")
# Out:
# 2021-07-02 14:41:28,933 - kedro.io.data_catalog - INFO - Loading data from `final_scaled_features` (CSVDataSet)...

# %%
scaled_features.head()
# Out:
#             D.YieldCurve  D.SahmRule  D.D.Ln.WagesPhillyMSA  \
# Date
# 1997-01-01     -0.028151    0.086667              -0.008285
# 1997-04-01     -0.098583   -0.223333              -0.005558
# 1997-07-01     -0.085312    0.103333               0.012688
# 1997-10-01     -0.166663   -0.066667               0.012970
# 1998-01-01     -0.030463    0.056667              -0.039897
#
#             D.Ln.NonfarmEmployeesPhillyMSA  D.Ln.NonfarmEmployeesPhilly  \
# Date
# 1997-01-01                        0.007211                    -0.008118
# 1997-04-01                        0.005163                    -0.001902
# 1997-07-01                        0.008757                     0.001302
# 1997-10-01                        0.008464                     0.009511
# 1998-01-01                        0.005303                     0.003315
#
#             D.Ln.PersonalSavingsRate  D.Ln.NYCGasPrice  D.Ln.CarSales  \
# Date
# 1997-01-01                 -0.021053         -0.058075       0.012176
# 1997-04-01                  0.056863         -0.084651      -0.045918
# 1997-07-01                 -0.083819          0.083351       0.046837
# 1997-10-01                  0.037538         -0.141757       0.019421
# 1998-01-01                  0.160148         -0.189621      -0.049476
#
#             D.Ln.RealRetailFoodServiceSales  D.Ln.UnemploymentRate  D.Ln.PPI  \
# Date
# 1997-01-01                         0.010423              -0.018928  0.000519
# 1997-04-01                        -0.004463              -0.045611 -0.010168
# 1997-07-01                         0.016635              -0.027029  0.000000
# 1997-10-01                        -0.000832              -0.041964  0.002356
# 1998-01-01                         0.004998              -0.007168 -0.019536
#
#             D.Ln.UnemploymentPhillyMSA  D.Ln.UnemploymentPhilly  \
# Date
# 1997-01-01                   -0.032157                -0.025541
# 1997-04-01                   -0.033226                -0.014045
# 1997-07-01                   -0.041385                -0.007421
# 1997-10-01                   -0.035846                -0.044643
# 1998-01-01                   -0.029632                -0.002417
#
#             D.Ln.CorporateProfits  D.Ln.RealGDP  D.Ln.AlcoholSales  \
# Date
# 1997-01-01               0.034092      0.006435           0.022644
# 1997-04-01               0.026578      0.016483           0.021473
# 1997-07-01               0.039824      0.012431           0.011972
# 1997-10-01              -0.016932      0.008551           0.018992
# 1998-01-01              -0.081392      0.009945           0.014810
#
#             D.Ln.PrimeEPOP  D.Ln.UncertaintyIndex  \
# Date
# 1997-01-01       -0.000414              -0.059453
# 1997-04-01        0.002894               0.299199
# 1997-07-01        0.005353              -0.268545
# 1997-10-01       -0.001644               0.130184
# 1998-01-01       -0.000411               0.227152
#
#             D.D.Ln.HousePriceIndexPhillyMSA  D.Ln.BuildingPermitsPhillyMSA  \
# Date
# 1997-01-01                        -0.006241                       0.049726
# 1997-04-01                        -0.006567                      -0.090230
# 1997-07-01                         0.012143                      -0.023355
# 1997-10-01                         0.001062                       0.056339
# 1998-01-01                         0.008234                       0.189062
#
#             D.EconomicConditionsPhillyMSA  D.Ln.CPIPhillyMSA  \
# Date
# 1997-01-01                       0.216667           0.006614
# 1997-04-01                      -0.070000           0.002961
# 1997-07-01                       0.820000           0.004391
# 1997-10-01                      -0.476667          -0.000259
# 1998-01-01                      -1.206667           0.001211
#
#             D.Ln.InitialClaimsPA  D.Ln.ContinuedClaimsPA  \
# Date
# 1997-01-01             -0.142231               -0.028216
# 1997-04-01              0.087875               -0.030346
# 1997-07-01              0.017352               -0.014462
# 1997-10-01              0.007374                0.016934
# 1998-01-01              0.012982               -0.016309
#
#             D.Ln.NewManufacturingOrders  D.Ln.ConsumerConfidence  \
# Date
# 1997-01-01                     0.028148                 0.002462
# 1997-04-01                     0.027674                 0.005314
# 1997-07-01                     0.072510                 0.003295
# 1997-10-01                    -0.019323                -0.000241
# 1998-01-01                    -0.000604                 0.002640
#
#             D.Ln.ManufacturingHoursWorked  D.Ln.PCE  \
# Date
# 1997-01-01                       0.001604  0.014896
# 1997-04-01                       0.002401  0.006994
# 1997-07-01                      -0.000800  0.019535
# 1997-10-01                       0.004789  0.015026
# 1998-01-01                      -0.003190  0.010136
#
#             D.Ln.RealDisposablePersonalIncome  D.Ln.HousingStarts  \
# Date
# 1997-01-01                           0.009479            0.010996
# 1997-04-01                           0.008829            0.029798
# 1997-07-01                           0.011695           -0.012499
# 1997-10-01                           0.014623            0.049737
# 1998-01-01                           0.020831            0.017257
#
#             D.Ln.HousingSupply  D.D.Ln.GovtSocialBenefits  D.Ln.GDPPriceIndex  \
# Date
# 1997-01-01           -0.172246                   0.014748            0.004470
# 1997-04-01            0.029632                  -0.017957            0.004975
# 1997-07-01           -0.060169                  -0.002059            0.002954
# 1997-10-01           -0.023530                  -0.000816            0.003574
# 1998-01-01           -0.048790                   0.011728            0.001015
#
#             D.Ln.GDP  D.Ln.PCEPriceIndex  D.Ln.CPIU  D.Ln.10YearTreasury  \
# Date
# 1997-01-01  0.012379            0.004405   0.006074             0.034094
# 1997-04-01  0.018502            0.002504   0.002294             0.020111
# 1997-07-01  0.016762            0.002636   0.004988            -0.070096
# 1997-10-01  0.011829            0.003132   0.005375            -0.055433
# 1998-01-01  0.011408            0.000076   0.002060            -0.055699
#
#             D.Ln.3MonthTreasury  D.Ln.FedFundsRate  D.Ln.OilPriceWTI  \
# Date
# 1997-01-01             0.016606          -0.000632         -0.078013
# 1997-04-01            -0.002639           0.045687         -0.132946
# 1997-07-01             0.000000           0.001809         -0.006209
# 1997-10-01             0.008550          -0.004831          0.007379
# 1998-01-01            -0.007230           0.002418         -0.222726
#
#             D.Ln.FHFAHousePriceIndex  D.Ln.NonfarmEmployment  \
# Date
# 1997-01-01                  0.006280                0.006208
# 1997-04-01                  0.008115                0.007146
# 1997-07-01                  0.007289                0.005812
# 1997-10-01                  0.010752                0.007876
# 1998-01-01                  0.012372                0.006096
#
#             D.Ln.PersonalIncome  D.Ln.Wage&Salaries  \
# Date
# 1997-01-01             0.017722            0.019277
# 1997-04-01             0.011878            0.015572
# 1997-07-01             0.015969            0.017402
# 1997-10-01             0.019115            0.022656
# 1998-01-01             0.021968            0.020454
#
#             D.Ln.NonresidentialInvestment  D.Ln.ResidentialInvestment  \
# Date
# 1997-01-01                       0.021638                    0.009772
# 1997-04-01                       0.019911                    0.018758
# 1997-07-01                       0.042293                    0.017771
# 1997-10-01                       0.002339                    0.017790
# 1998-01-01                       0.026118                    0.023296
#
#             D.Ln.TotalBusinessSales  D.Ln.SP500  D.D.Ln.MedianHomeValuePhilly  \
# Date
# 1997-01-01                 0.019385    0.077793                      0.003977
# 1997-04-01                 0.006936    0.048265                     -0.001109
# 1997-07-01                 0.015111    0.120323                     -0.001461
# 1997-10-01                 0.006278    0.022298                     -0.005815
# 1998-01-01                 0.005541    0.071520                     -0.000397
#
#             D.Ln.AmusementBase  D.GrossReceiptsBase  D.NetIncomeBase  \
# Date
# 1997-01-01           -0.750555             0.043920         0.040621
# 1997-04-01            0.674485             0.167152         0.138132
# 1997-07-01           -0.143395            -0.018339        -0.021556
# 1997-10-01            0.317877             0.063651         0.061508
# 1998-01-01           -0.638450            -0.040535        -0.046653
#
#             D.NPTBase  D.Ln.ParkingBase  D.Ln.RTTBase  D.Ln.SalesBase  \
# Date
# 1997-01-01   0.074343         -0.016236     -0.369991        0.075583
# 1997-04-01  -0.018271          0.089694     -0.014438       -0.094648
# 1997-07-01   0.048985         -0.087370      0.410222        0.288893
# 1997-10-01  -0.060980          0.064860      0.187705       -0.223446
# 1998-01-01   0.098343         -0.008739     -0.017401       -0.021794
#
#             D.Ln.WageBase
# Date
# 1997-01-01       0.049908
# 1997-04-01      -0.047583
# 1997-07-01       0.039920
# 1997-10-01       0.016527
# 1998-01-01       0.050521

# %% [markdown]
# Determine the name of the scaled tax base column:

# %%
SCALED_COLUMN = [col for col in scaled_features.columns if TAX_BASE_COLUMN in col][0]

# %%
SCALED_COLUMN
# Out:
# 'D.Ln.SalesBase'

# %% [markdown]
# Initialize the preprocesser that goes from unscaled to scaled features:

# %%
guide = DATA.load("stationary_guide")
preprocess = PreprocessPipeline(guide)
# Out:
# 2021-07-02 14:41:29,844 - kedro.io.data_catalog - INFO - Loading data from `stationary_guide` (ExcelDataSet)...

# %%
guide.head()
# Out:
#                  variable  ndiffs  loggable  norm  periods
# 0   BuildingPermitsPhilly       1      True     1        1
# 1  ActivityLicensesPhilly       1      True     1        1
# 2       BizLicensesPhilly       2      True     1        1
# 3     DeedTransfersPhilly       1      True     1        1
# 4              YieldCurve       1     False     1        1

# %% [markdown]
# Load the CBO data frame:

# %%
cbo_data = load_cbo_data(date=cbo_forecast_date)
cbo_columns = cbo_data.columns.tolist()

# %%
cbo_data.head()
# Out:
# var1        10YearTreasury  3MonthTreasury     CPIU  CorporateProfits  \
# Date
# 2017-01-01           2.443           0.590  243.752            2064.1
# 2017-04-01           2.263           0.890  244.187            2103.0
# 2017-07-01           2.243           1.036  245.345            2136.0
# 2017-10-01           2.370           1.206  247.257            2155.0
# 2018-01-01           2.760           1.560  249.179            2206.0
#
# var1        FHFAHousePriceIndex  FedFundsRate  GDPPriceIndex  \
# Date
# 2017-01-01               235.71         0.700        107.031
# 2017-04-01               240.00         0.950        107.368
# 2017-07-01               243.79         1.153        107.968
# 2017-10-01               247.36         1.203        108.637
# 2018-01-01               252.08         1.446        109.292
#
# var1        NonfarmEmployment  NonresidentialInvestment  OilPriceWTI      PCE  \
# Date
# 2017-01-01           145780.0                    2532.5        51.77  13153.2
# 2017-04-01           146318.0                    2555.9        48.24  13241.3
# 2017-07-01           146874.0                    2575.2        48.16  13370.9
# 2017-10-01           147405.0                    2634.2        55.37  13596.0
# 2018-01-01           147988.0                    2716.2        62.89  13755.5
#
# var1        PCEPriceIndex  PersonalIncome  RealGDP  ResidentialInvestment  \
# Date
# 2017-01-01        105.421         16633.7  17977.3                  746.0
# 2017-04-01        105.654         16828.4  18054.1                  753.3
# 2017-07-01        106.084         17036.6  18185.6                  758.5
# 2017-10-01        106.775         17295.6  18359.4                  783.6
# 2018-01-01        107.485         17548.6  18530.5                  794.3
#
# var1        UnemploymentRate  Wage&Salaries
# Date
# 2017-01-01             4.566         8308.8
# 2017-04-01             4.400         8399.9
# 2017-07-01             4.300         8515.3
# 2017-10-01             4.133         8661.8
# 2018-01-01             4.033         8756.4

# %% [markdown]
# ## Forecast
#
# In this section, we use a combination of correlations, Granger matrix, and intuition to select possible endogenous variables to include in the VAR fit. Then, we do a grid search to find the bestfit parameters based on accuracy on historical data:

# %% [markdown]
# ### Correlations
#
# Get top and bottom 10 correlations with our tax base:

# %%
C[SCALED_COLUMN].sort_values().head(n=10)
# Out:
# D.Ln.UnemploymentRate               -0.407223
# D.Ln.UnemploymentPhillyMSA          -0.397288
# D.Ln.ContinuedClaimsPA              -0.395587
# D.Ln.UnemploymentPhilly             -0.379954
# D.D.Ln.GovtSocialBenefits           -0.325061
# D.SahmRule                          -0.313244
# D.Ln.PersonalSavingsRate            -0.244515
# D.Ln.RealDisposablePersonalIncome   -0.238336
# D.Ln.PersonalIncome                 -0.206191
# D.Ln.InitialClaimsPA                -0.198710
# Name: D.Ln.SalesBase, dtype: float64

# %%
C[SCALED_COLUMN].sort_values().tail(n=10)
# Out:
# D.Ln.PCE                          0.399442
# D.Ln.NonfarmEmployeesPhilly       0.409485
# D.Ln.RTTBase                      0.413431
# D.Ln.ParkingBase                  0.413450
# D.Ln.NonfarmEmployment            0.420213
# D.Ln.PrimeEPOP                    0.420751
# D.Ln.NonfarmEmployeesPhillyMSA    0.429908
# D.Ln.GDP                          0.448069
# D.Ln.RealGDP                      0.451292
# D.Ln.SalesBase                    1.000000
# Name: D.Ln.SalesBase, dtype: float64

# %% [markdown]
# Load the possible endog variables:

# %%
possible_endog = DATA.load('possible_endog_variables')[SCALED_COLUMN]
# Out:
# 2021-07-02 13:41:32,713 - kedro.io.data_catalog - INFO - Loading data from `possible_endog_variables` (JSONDataSet)...

# %%
possible_endog
# Out:
# ['WageBase', 'FHFAHousePriceIndex', 'PrimeEPOP']

# %% [markdown]
# ### Run the grid search
#
# This can take some time to run depending on how many variables we are searching over:

# %%
all_fits = run_possible_models(
    unscaled_features,
    preprocess,
    main_endog=TAX_BASE_COLUMN,
    other_endog=[
        "ConsumerConfidence",
        "CarSales",
        "AlcoholSales",
        "TotalBusinessSales",
        "NonfarmEmployeesPhillyMSA",
        "UnemploymentPhillyMSA",
    ],
    orders=[2, 3, 4, 5, 6],
    grangers=G,
    max_fit_date=["2019-12-31", "2021-06-30"],
    cbo_columns=cbo_columns,
    alpha=0.05,
    max_exog=2,
    max_other_endog=1,
    model_quarters=[True, False],
)
# Out:
# 2021-07-02 14:32:33.303 | INFO     | fyp_analysis.pipelines.modeling.predict.core:run_possible_models:578 - Running fits for 760 sets of parameters
# 2021-07-02 14:32:33.304 | INFO     | fyp_analysis.pipelines.modeling.predict.core:grid_search_var_model:409 - Running grid search in parallel with 4 processes
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 760/760 [03:39<00:00,  3.46it/s]

# %% [markdown]
# Split fits that do and do not have at least one CBO variable as exogenous variable:

# %%
fits_with_exog = list(filter(lambda d: len(d["exog_cols"]) > 0, all_fits))
fits_no_exog = list(filter(lambda d: len(d["exog_cols"]) == 0, all_fits))

# %% [markdown]
# Compare the historical accuracy of the top fits with and without exog variables:

# %%
with plt.style.context(get_theme()):

    fig, ax = plt.subplots()

    ax.hist(
        [d["target_mape"] for d in fits_with_exog[:20] if d["target_mape"] < 1],
        bins="auto",
        histtype="step",
        label="With Exog",
        zorder=10,
        lw=2,
    )
    ax.hist(
        [d["target_mape"] for d in fits_no_exog[:20] if d["target_mape"] < 1],
        bins="auto",
        histtype="step",
        label="No Exog",
        lw=2,
    )
    ax.legend()

# %% [markdown]
# ### Run the VAR with the best-fit params

# %%
best_params = all_fits[0]
best_params
# Out:
# {'mape_splits': [SalesBase    0.038556
#   CarSales     0.159179
#   dtype: float64,
#   SalesBase    0.076191
#   CarSales     0.363665
#   dtype: float64,
#   SalesBase    0.068957
#   CarSales     0.051513
#   dtype: float64],
#  'mape': SalesBase    0.061234
#  CarSales     0.191452
#  dtype: float64,
#  'order': 2,
#  'endog_cols': ['SalesBase', 'CarSales'],
#  'exog_cols': ['OilPriceWTI'],
#  'model_quarters': False,
#  'model_covid': False,
#  'max_fit_date': '2021-06-30',
#  'target_mape': 0.06123446811395171}

# %%
result, forecast = fit_var_model(
    unscaled_features,
    preprocess,
    plan_start_year=plan_start_year,
    max_fit_date=best_params["max_fit_date"],
    cbo_data=cbo_data,
    endog_cols=best_params["endog_cols"],
    order=best_params["order"],
    exog_cols=best_params["exog_cols"],
    model_quarters=best_params["model_quarters"],
)
print(result.aic)
# Out:
# -10.085722804837022

# %%
result.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 02, Jul, 2021
# Time:                     14:37:37
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.76518
# Nobs:                     96.0000    HQIC:                  -9.95615
# Log likelihood:           223.678    FPE:                4.16839e-05
# AIC:                     -10.0857    Det(Omega_mle):     3.69241e-05
# --------------------------------------------------------------------
# Results for equation D.Ln.SalesBase
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.012089         0.010233            1.181           0.237
# D.Ln.OilPriceWTI          0.151143         0.061380            2.462           0.014
# L1.D.Ln.SalesBase        -0.674320         0.097463           -6.919           0.000
# L1.D.Ln.CarSales          0.301837         0.155055            1.947           0.052
# L2.D.Ln.SalesBase        -0.394610         0.097423           -4.050           0.000
# L2.D.Ln.CarSales          0.092020         0.157767            0.583           0.560
# ====================================================================================
#
# Results for equation D.Ln.CarSales
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.000668         0.006361            0.105           0.916
# D.Ln.OilPriceWTI          0.197654         0.038158            5.180           0.000
# L1.D.Ln.SalesBase        -0.060125         0.060589           -0.992           0.321
# L1.D.Ln.CarSales         -0.143828         0.096392           -1.492           0.136
# L2.D.Ln.SalesBase        -0.044678         0.060564           -0.738           0.461
# L2.D.Ln.CarSales         -0.071145         0.098078           -0.725           0.468
# ====================================================================================
#
# Correlation matrix of residuals
#                   D.Ln.SalesBase  D.Ln.CarSales
# D.Ln.SalesBase          1.000000       0.155495
# D.Ln.CarSales           0.155495       1.000000

# %%
fig = plot_forecast_results(forecast, TAX_BASE_COLUMN);
# Out:
# 2021-07-02 14:37:38.546 | INFO     | fyp_analysis.pipelines.modeling.predict.viz:plot_forecast_results:62 - Year-over-Year Change
# 2021-07-02 14:37:38.548 | INFO     | fyp_analysis.pipelines.modeling.predict.viz:plot_forecast_results:63 - 2020   -0.060465
# 2021    0.015864
# 2022    0.050293
# 2023    0.016952
# 2024    0.021614
# 2025    0.023804
# 2026    0.026362
# Name: SalesBase, dtype: float64

# %% [markdown]
# ### Compare to Budget Office Projections

# %% [markdown]
# Aggregate to fiscal year:

# %%
[d['target_mape'] for d in all_fits[:10]]
# Out:
# [0.06123446811395171,
#  0.06137575322075062,
#  0.06231465315359751,
#  0.06388888737947301,
#  0.06461218974506228,
#  0.06468340121791082,
#  0.0648703227306231,
#  0.06541979102519001,
#  0.06651762166982199,
#  0.06705952259366241]

# %%
TOP = 3

all_forecasts = get_forecasts_from_fits(
    unscaled_features,
    preprocess,
    all_fits,
    TAX_BASE_COLUMN,
    plan_start_year,
    cbo_data,
    max_fits=TOP,
)

# %%
average_fit = all_forecasts.mean(axis=1).squeeze().rename(TAX_BASE_COLUMN)

# %% [markdown]
# Plot:

# %%
plot_projection_comparison(this_tax, average_fit);

# %% [markdown]
# ### Save Best-fit Parameters

# %%
DATA.save("sales_fit_params", all_fits[:TOP])
# Out:
# 2021-07-02 14:39:39,381 - kedro.io.data_catalog - INFO - Saving data to `sales_fit_params` (PickleDataSet)...
